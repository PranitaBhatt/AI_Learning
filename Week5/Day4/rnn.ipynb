# %%
#performing a text generator using RNN
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense #importing rnn model

# %%
text = "This is a example for implementing a Text Generator using Recurrent Neural Network.We are implementing this using Tensorflow and keras." \
" We will be using a simple RNN model for this task. The model will be trained on a sample text and then it will generate new text based on the learned patterns." \
"Recurrent Neural Networks (RNNs) are a class of neural networks designed to process sequential data by retaining information from previous steps. They are especially effective for tasks where context and order matter." \
"Imagine reading a sentence and you try to predict the next word, you don’t rely only on the current word but also remember the words that came before. RNNs work similarly by “remembering” past information i.e it considers all the earlier words to choose the most likely next word."\
"This memory of previous steps helps the network understand context and make better predictions." \
"The fundamental processing unit in RNN is a Recurrent Unit. They hold a hidden state that maintains information about previous inputs in a sequence. Recurrent units can remember information from prior steps by feeding back their hidden state, allowing them to capture dependencies across time."\
"RNN unfolding or unrolling is the process of expanding the recurrent structure over time steps. During unfolding each step of the sequence is represented as a separate layer in a series illustrating how information flows across each time step."\
"This unrolling enables backpropagation through time (BPTT) a learning process where errors are propagated across time steps to adjust the network’s weights enhancing the RNN’s ability to learn dependencies within sequential data."

text = text.replace("“", '"')
text = text.replace("”", '"')
text = text.replace("’", "'")
import re

text = re.sub(r'[^A-Za-z0-9.,!? ]+', '', text)
text = text.lower()

# %%
# unique sorted characters
chars = sorted(set(text))

# empty dictionaries
char_to_index = {}
index_to_char = {}

# filling dictionaries
for i, char in enumerate(chars):
    char_to_index[char] = i
    index_to_char[i] = char

# %%
#Create sequences and labels
seq_length = 30
sequences = []
labels = []

for i in range(len(text) - seq_length):
    seq = text[i:i + seq_length]
    label = text[i + seq_length]
    sequences.append([char_to_index[char] for char in seq])
    labels.append(char_to_index[label])

X = np.array(sequences)
y = np.array(labels)

# %%
#performing one hot encoding
X_one_hot = tf.one_hot(X, len(chars))
y_one_hot = tf.one_hot(y, len(chars))

# %%
#buidling the rnn model
model = Sequential()
model.add(LSTM(128, input_shape=(seq_length, len(chars))))
model.add(Dense(len(chars), activation='softmax'))
# Out:
# c:\Users\PranitaBhatt\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.fit(
    X_one_hot,
    y_one_hot,
    epochs=50,
    batch_size=32
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1432 - loss: 2.9921
# Epoch 2/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1606 - loss: 2.8777
# Epoch 3/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1562 - loss: 2.8435
# Epoch 4/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1631 - loss: 2.8161
# Epoch 5/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1730 - loss: 2.7738
# Epoch 6/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2244 - loss: 2.7056
# Epoch 7/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2523 - loss: 2.6194
# Epoch 8/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2672 - loss: 2.5343
# Epoch 9/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2970 - loss: 2.4504
# Epoch 10/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3236 - loss: 2.3767
# Epoch 11/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3360 - loss: 2.3039
# Epoch 12/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3521 - loss: 2.2591
# Epoch 13/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3577 - loss: 2.2053
# Epoch 14/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3738 - loss: 2.1614
# Epoch 15/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3875 - loss: 2.1049
# Epoch 16/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4011 - loss: 2.0640
# Epoch 17/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4135 - loss: 2.0014
# Epoch 18/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4247 - loss: 1.9641
# Epoch 19/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4234 - loss: 1.9186
# Epoch 20/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4439 - loss: 1.8611
# Epoch 21/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4774 - loss: 1.7970
# Epoch 22/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4836 - loss: 1.7649
# Epoch 23/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4916 - loss: 1.6993
# Epoch 24/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5170 - loss: 1.6436
# Epoch 25/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5449 - loss: 1.5750
# Epoch 26/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5561 - loss: 1.5160
# Epoch 27/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5778 - loss: 1.4567
# Epoch 28/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6057 - loss: 1.3875
# Epoch 29/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6082 - loss: 1.3306
# Epoch 30/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6373 - loss: 1.2661
# Epoch 31/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6795 - loss: 1.1932
# Epoch 32/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6993 - loss: 1.1146
# Epoch 33/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7148 - loss: 1.0489
# Epoch 34/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7421 - loss: 0.9697
# Epoch 35/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7607 - loss: 0.9253
# Epoch 36/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7774 - loss: 0.8672
# Epoch 37/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8115 - loss: 0.7731
# Epoch 38/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8345 - loss: 0.7267
# Epoch 39/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8363 - loss: 0.6907
# Epoch 40/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8686 - loss: 0.6160
# Epoch 41/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8971 - loss: 0.5460
# Epoch 42/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9151 - loss: 0.5004
# Epoch 43/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9237 - loss: 0.4505
# Epoch 44/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9275 - loss: 0.4106
# Epoch 45/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9535 - loss: 0.3541
# Epoch 46/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9597 - loss: 0.3080
# Epoch 47/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9727 - loss: 0.2765
# Epoch 48/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9833 - loss: 0.2366
# Epoch 49/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9913 - loss: 0.1976
# Epoch 50/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9882 - loss: 0.1949

# %%
start_seq = text[:seq_length]
generated_text = start_seq

for i in range(100):

    # last sequence, always the same length used during training
    seq = generated_text[-seq_length:]

    # convert chars to indices
    x = [char_to_index[c] for c in seq]

    # reshape
    x = np.array(x).reshape(1, -1)

    # one hot encoding
    x_one_hot = tf.one_hot(x, len(chars))

    # prediction probabilities for the next character
    prediction = model.predict(x_one_hot, verbose=0)[0]

    # choose the most likely character instead of sampling random characters
    next_index = np.argmax(prediction)

    # char
    next_char = index_to_char[next_index]

    # append
    generated_text += next_char

print(generated_text)
# Out:
# this is a example for implementing a text generator using recurrent neural network.we are implementing this using tensorflow and k

# %%
print(prediction.shape)
# Out:
# (28,)
